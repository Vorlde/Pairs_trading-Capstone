# %%
! pip install dill
! pip install statsmodels

import pandas as pd
import numpy as np
from datetime import datetime, timedelta


from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import preprocessing

from statsmodels.tsa.stattools import coint

from scipy import stats
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (0.3.8)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.25.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (2.0.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
# !pip install hurst
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller as ADF_test
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: hurst in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.10/dist-packages (from hurst) (2.0.3)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.10/dist-packages (from hurst) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->hurst) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->hurst) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->hurst) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18->hurst) (1.16.0)

# %%
import lzma
import dill as pickle

def save_pickle(path,obj):
    with lzma.open(path,"wb") as fp:
        pickle.dump(obj,fp)

def load_pickle(path):
    with lzma.open(path,"rb") as fp:
        file = pickle.load(fp)
    return file


def clean_data(ticker_dfs,tickers):
    intraday_range = ticker_dfs[tickers[0]].index
    for inst in tickers:
        ticker_dfs[inst] = ticker_dfs[inst].reindex(intraday_range)
    closes = []

    for tk in tickers:
        close = ticker_dfs[tk].close
        closes.append(close)

    pricing = pd.concat(closes,axis = 1)
    pricing.columns = tickers

    return pricing




def get_pca_features(ret_df,N_PRIN_COMPONENTS =10):

    pca = PCA(n_components=N_PRIN_COMPONENTS)
    pca.fit(ret_df)

    # Extract factor loadings
    factor_loadings = pca.components_.T  # Transpose the components matrix

    # Create a DataFrame with the correct orientation
    factor_loadings_df = pd.DataFrame(factor_loadings, index=ret_df.columns, columns=[f'Factor {i+1}' for i in range(N_PRIN_COMPONENTS)])

    X = preprocessing.StandardScaler().fit_transform(pca.components_.T)

    return X

def create_clusters(X,index):
    clf = DBSCAN(eps=1, min_samples=3)

    print(clf)

    clf.fit(X)
    labels = clf.labels_
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    print("\nClusters discovered: %d" % n_clusters_)

    clustered = clf.labels_

    clustered_series = pd.Series(index=index, data=clustered.flatten())
    clustered_series = clustered_series[clustered_series != -1]

    return clustered_series


def find_cointegrated_pairs(data, significance=0.05):
    # This function is from https://www.quantopian.com/lectures/introduction-to-pairs-trading
    n = data.shape[1]
    score_matrix = np.zeros((n, n))
    pvalue_matrix = np.ones((n, n))
    keys = data.keys()
    pairs = []
    for i in range(n):
        for j in range(i+1, n):
            S1 = data[keys[i]]
            S2 = data[keys[j]]
            result = coint(S1, S2)
            score = result[0]
            pvalue = result[1]
            score_matrix[i, j] = score
            pvalue_matrix[i, j] = pvalue
            if pvalue < significance:
                pairs.append((keys[i], keys[j]))
    return score_matrix, pvalue_matrix, pairs



def get_coint_pairs(prices,clustered_series):

    valid_tickers = clustered_series.index.intersection(prices.columns)
    clustered_series = clustered_series.loc[valid_tickers]

    CLUSTER_SIZE_LIMIT = 9999
    counts = clustered_series.value_counts()
    ticker_count_reduced = counts[(counts>1) & (counts<=CLUSTER_SIZE_LIMIT)]

    cluster_dict = {}
    for i, which_clust in enumerate(ticker_count_reduced.index):
        tickers = clustered_series[clustered_series == which_clust].index
        score_matrix, pvalue_matrix, pairs = find_cointegrated_pairs(
            prices[tickers]
        )
        cluster_dict[which_clust] = {}
        cluster_dict[which_clust]['score_matrix'] = score_matrix
        cluster_dict[which_clust]['pvalue_matrix'] = pvalue_matrix
        cluster_dict[which_clust]['pairs'] = pairs

    pairs = []
    for clust in cluster_dict.keys():
        pairs.extend(cluster_dict[clust]['pairs'])

    return pairs


def get_data():
    data_path = "/content/drive/My Drive/constituents.csv"
    dfs_path = "/content/drive/My Drive/new_dfs.obj"

    ticker_dfs = load_pickle(dfs_path)
    snp_data = pd.read_csv(data_path)
    tickers = []

    for i in range(499):
      tickers.append(snp_data.Symbol[i])

    tickers.remove("BF.B")
    tickers.remove("BRK.B")
    tickers.remove("CPAY")
    tickers.remove("DAY")
    tickers.remove("GEV")
    tickers.remove("SOLV")

    return tickers,ticker_dfs

# %%
import statsmodels.api as sm
from hurst import compute_Hc  # Assuming you have a function to compute the Hurst exponent

def process_pair_and_store(pair, prices, h5_file_path):
    s1, s2 = pair

    datax = prices[s1]
    datay = prices[s2]

    # Find the hedge ratio using OLS on the first 500 data points
    hedge_ratio = sm.OLS(datax[:500], sm.add_constant(datay[:500])).fit().params[1]

    # Calculate the normalized spread based on the hedge ratio
    spread = datax - hedge_ratio * datay
    spread_normalized = (spread - spread.mean()) / spread.std()

    # Calculate features for the first 500 points
    rolling_volatility = spread_normalized[:500].rolling(window=10).std()
    hurst_exponent = compute_Hc(spread_normalized[:500])[0]  # Hurst exponent
    spread_normalized = spread_normalized[:500]  # Normalized spread

    features_df = pd.DataFrame({
        'spread_normalized': spread_normalized,
        'rolling_volatility': rolling_volatility[:500],
        'hurst_exponent': np.repeat(hurst_exponent, rolling_volatility.shape[0]),
        'hedge_ratio': np.repeat(hedge_ratio, rolling_volatility.shape[0])
    })

    # Perform ADF test on the first 500 points for stationarity
    adf_result_train = ADF_test(spread_normalized)
    print(pair, adf_result_train[1])
    print(features_df)
    print(features_df.shape)

    features_df.dropna(inplace = True)
    features_df = features_df.reset_index()

    print(features_df)
    print(features_df.shape)


    # Proceed only if the first 500 points spread is stationary
    if adf_result_train[1] < 0.05:
        stationarity_train = adf_result_train[1] < 0.05

        # The stationarity status of the next 124 points and the hedge ratio for those points are used as labels for training the models
        stationarity_test = ADF_test(spread[500:])[1] < 0.05
        hedge_ratio_test = hedge_ratio

        # Store the features and labels in HDF5 file for LSTM training
        # store_to_hdf5(h5_file_path, pair, features_df, stationarity_train, stationarity_test, hedge_ratio_test)
        input(spread_normalized)

        spread_normalized = spread_normalized.reset_index(drop=True)
        input(spread_normalized)
        plt.figure(figsize=(15, 7))
        plt.title(f'Z-Scores for {s1} and {s2} Across Training and Testing Periods')
        spread_normalized.plot()
        plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

tickers,ticker_dfs = get_data()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def generate_trading_data_blocks(df, month,year,days_per_block=9, step_days=5):
    """
    Generate rolling blocks of data consisting of 9 trading days,
    advancing the window by 5 days after each block from the original dataframe.
    """

    if month == 12:
      month = 1
      year +=1

    else:
      month+=1

    month_data =df[(df.index.year == year) & (df.index.month == month)]

    # Extract unique trading days from the index
    unique_days = month_data.index.normalize().unique()

    for start_day_idx in range(0, len(unique_days) - days_per_block + 1, step_days):
        # Identify start and end day for the block
        start_day = unique_days[start_day_idx]
        end_day_idx = start_day_idx + days_per_block - 1  # inclusive end day index
        if end_day_idx >= len(unique_days):  # Ensure we don't go out of bounds
            break
        end_day = unique_days[end_day_idx]

        # Slice the original dataframe to get the block data
        block_data = month_data[start_day:end_day]
        print(f"yeilding block data for {month} {year}")
        yield block_data


def calculate_monthly_clusters(monthly_data):
    """
    Calculate clusters for the given month.

    """
    ret_df = monthly_data.pct_change().round(4).fillna(0)
    X = get_pca_features(ret_df)
    clustered_series = create_clusters(X, ret_df.columns)

    return clustered_series


def yield_monthly_data(df):
    """
    Yields each month's data from the dataframe.
    """
    for year in df.index.year.unique():
        for month in df[df.index.year == year].index.month.unique():
            monthly_data = df[(df.index.year == year) & (df.index.month == month)]
            yield year, month, monthly_data

# %%
import statsmodels.api as sm
from hurst import compute_Hc  # Assuming you have a function to compute the Hurst exponent
from statsmodels.tools.tools import add_constant
from scipy.stats import skew, kurtosis

def add_stationary(spread_normalized):

    rolling_volatility = spread_normalized[:500].rolling(window=10).std()
    hurst_exponent = compute_Hc(spread_normalized[:500])[0]  # Hurst exponent

    skewness = skew(spread_normalized[:500])
    kurtosis_value = kurtosis(spread_normalized[:500])


    # Ensure spread_lagged starts from the second element to align with spread_diff which starts from the second element due to differencing and shifting
    spread_lagged = spread_normalized.shift(1).dropna()
    spread_diff = spread_normalized.diff().dropna()  # First difference to get spread_diff

    # Make sure indices are aligned by reindexing spread_diff to match spread_lagged
    spread_diff = spread_diff.reindex(spread_lagged.index)
    spread_diff += 1e-8

    # Now perform your regression with aligned indices
    model = sm.OLS(np.log(np.abs(spread_diff)), add_constant(spread_lagged))
    result = model.fit()
    phi = result.params[0]


    spread_normalized = spread_normalized[:500]  # Normalized spread

    features_df = pd.DataFrame({
        'spread_normalized': spread_normalized,
        'rolling_volatility': rolling_volatility[:500],
        'hurst_exponent': np.repeat(hurst_exponent, rolling_volatility.shape[0]),
    })

    # Mean Reversion Speed calculated as the absolute value of phi
    mean_reversion_speed = np.abs(phi)

    # Calculate half-life from the decay factor
    half_life = -np.log(2) / np.log(np.abs(phi))


    features_df['half_life'] = np.repeat(half_life, len(features_df))
    features_df['mean_reversion_speed'] = np.repeat(mean_reversion_speed, len(features_df))
    features_df['skewness'] = np.repeat(skewness, len(features_df))
    features_df['kurtosis'] = np.repeat(kurtosis_value, len(features_df))

    return features_df



def process_pair(pair, prices):
    s1, s2 = pair

    datax = prices[s1]
    datay = prices[s2]

    # Find the hedge ratio using OLS on the first 500 data points
    hedge_ratio = sm.OLS(datax[:500], sm.add_constant(datay[:500])).fit().params[1]

    # Calculate the normalized spread based on the hedge ratio
    spread = datax - hedge_ratio * datay
    spread_normalized = (spread - spread.mean()) / spread.std()

    features_df = add_stationary(spread_normalized)
    features_df['hedge_ratio'] = np.repeat(hedge_ratio, len(features_df))

    # Perform ADF test on the first 500 points for stationarity
    adf_result_train = ADF_test(spread_normalized)
    print(pair, adf_result_train[1], )

    features_df.dropna(inplace = True)
    # print(features_df)



    # Proceed only if the first 500 points spread is stationary
    if adf_result_train[1] < 0.05:
        stationarity_train = adf_result_train[1] < 0.05

        # The stationarity status of the next 124 points and the hedge ratio for those points are used as labels for training the models
        stationarity_test = ADF_test(spread[500:])[1] < 0.05
        hedge_ratio_test = hedge_ratio

        # spread_normalized = spread_normalized.reset_index(drop=True)
        # plt.figure(figsize=(15, 7))
        # plt.title(f'Z-Scores for {s1} and {s2} Across Training and Testing Periods')
        # spread_normalized.plot()
        # plt.show()

        print(f"hedge_ratio_test {hedge_ratio_test}")
        print(f"stationarity_test {stationarity_test}")

        return features_df, stationarity_test, hedge_ratio_test

# %%
def initialize_hdf5_structure(h5_file_path):
    with pd.HDFStore(h5_file_path, mode='a') as store:
        # Create an empty DataFrame with expected structure for 'features' if it doesn't exist
        if 'features' not in store:
            store.put('features', pd.DataFrame(), format='table', data_columns=True)
        # Create empty series for 'stationarity_labels' and 'hedge_ratios' if they don't exist
        if 'stationarity_labels' not in store:
            store.put('stationarity_labels', pd.Series(dtype='int'), format='table')
        if 'hedge_ratios' not in store:
            store.put('hedge_ratios', pd.Series(dtype='float'), format='table')


import pandas as pd
import numpy as np
import os

def store_data(features_list, stationarity_labels, hedge_ratios, hdf5_file_path, current_batch_index=None):
    if not features_list:
        return  # Early exit if no features to store

    with pd.HDFStore(hdf5_file_path, mode='a') as store:
        # Determine the current batch index if not provided
        if current_batch_index is None:
            if '/features' in store.keys():
                # Compute the next batch index based on existing data
                current_batch_index = store.get_storer('features').nrows
            else:
                current_batch_index = 0

        # Create a MultiIndex DataFrame from the list
        keys = list(range(current_batch_index, current_batch_index + len(features_list)))
        features_df = pd.concat(features_list, keys=keys, names=['batch', 'row'])

        # Append the features DataFrame to the store
        if '/features' in store.keys():
            store.append('features', features_df, format='table', data_columns=True)
        else:
            store.put('features', features_df, format='table', data_columns=True)

        # Prepare and store stationarity labels
        if stationarity_labels:
            # Create a Series with a simple range index, assuming one label per batch
            labels_series = pd.Series(stationarity_labels, index=keys)
            if '/stationarity_labels' in store.keys():
                store.append('stationarity_labels', labels_series, format='table')
            else:
                store.put('stationarity_labels', labels_series, format='table')

        # Prepare and store hedge ratios
        if hedge_ratios:
            # Similarly, create a Series for hedge ratios
            ratios_series = pd.Series(hedge_ratios, index=keys)
            if '/hedge_ratios' in store.keys():
                store.append('hedge_ratios', ratios_series, format='table')
            else:
                store.put('hedge_ratios', ratios_series, format='table')

# %%
def main_driver_function(prices, store_file_path, track_completion_path):
    # Load or initialize the checkpoint
    completed_months = load_pickle(track_completion_path) if os.path.exists(track_completion_path) else {}

    for year, month, monthly_data in yield_monthly_data(prices):
        month_year_key = f"{month}{year}"

        # Check if the month has been processed
        if completed_months.get(month_year_key):
            print(f"Skipping already processed {month_year_key}.")
            continue

        print(f"Clustering for {month} {year}")
        cluster = calculate_monthly_clusters(monthly_data)

        for block_data in generate_trading_data_blocks(prices, month, year):
            if block_data.shape[0] == 624:
                block_data = block_data.dropna(axis=1)
                pairs = get_coint_pairs(block_data, cluster)

                features_list, stationarity_labels, hedge_ratios = [], [], []
                for pair in pairs:
                    result = process_pair(pair, block_data)
                    if result is not None:
                        features_df, stationarity_test, hedge_ratio_test = result
                        features_list.append(features_df)
                        stationarity_labels.append(stationarity_test)
                        hedge_ratios.append(hedge_ratio_test)

                # Store the processed data
                store_data(features_list, stationarity_labels, hedge_ratios, store_file_path)

        # Update the checkpoint after each month
        completed_months[month_year_key] = True
        save_pickle(track_completion_path, completed_months)

import os
# Paths
store_file_path = "/content/drive/My Drive/NN_dataset.h5"
track_completion_path = "/content/drive/My Drive/track_completion"

initialize_hdf5_structure(store_file_path)

intraday_dfs = ticker_dfs.copy()
prices = clean_data(intraday_dfs, tickers)

main_driver_function(prices[-3000:], store_file_path, track_completion_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('BAC', 'USB') 0.09455290037505215
# ('BAC', 'UNP') 0.00314779569358727
# hedge_ratio_test 0.031352957251925176
# stationarity_test False
# ('BAC', 'UPS') 0.004310948485661122
# hedge_ratio_test 0.05143313881502823
# stationarity_test False
# ('BAC', 'UNH') 0.0028442006559216753
# hedge_ratio_test -0.01909531288661083
# stationarity_test False
# ('BAC', 'VRSK') 0.002653951337929681
# hedge_ratio_test -0.014007622408985104
# stationarity_test False
# ('BAC', 'VZ') 0.0017071814882189933
# hedge_ratio_test 0.02900548399917946
# stationarity_test False
# ('BAC', 'V') 0.011261441981316862
# hedge_ratio_test 0.06713816017059285
# stationarity_test False
# ('BAC', 'WRB') 0.0009122602197539974
# hedge_ratio_test -0.0410613173900618
# stationarity_test False
# ('BAC', 'WM') 0.0010526555375529013
# hedge_ratio_test -0.08015825891542548
# stationarity_test False
# ('BAC', 'WFC') 0.09574265736422599
# ('BAC', 'XYL') 0.12213121292446988
# ('BK', 'VZ') 0.004618989595605254
# hedge_ratio_test -1.268324341480647
# stationarity_test False
# ('BRO', 'CTSH') 0.05152599512043293
# ('BRO', 'EA') 0.0204072253816247
# hedge_ratio_test 0.3351906887717796
# stationarity_test False
# ('BRO', 'FTV') 0.00412951643421994
# hedge_ratio_test 0.6013532994972688
# stationarity_test False
# ('BRO', 'IBM') 0.08182084386723232
# ('BRO', 'ICE') 3.346866996134047e-07
# hedge_ratio_test 0.34846491390447754
# stationarity_test False
# ('BRO', 'JPM') 0.1288028164619689
# ('BRO', 'LMT') 0.09619023079995687
# ('BRO', 'MET') 0.013332700129174414
# hedge_ratio_test 0.7310426028143655
# stationarity_test False
# ('BRO', 'TAP') 0.027133823172347415
# hedge_ratio_test 0.7760962160108966
# stationarity_test False
# ('BRO', 'VZ') 0.0225135652681362
# hedge_ratio_test -1.0877610504437234
# stationarity_test False
# ('BG', 'CAG') 0.002847549030536834
# hedge_ratio_test -3.86948638825156
# stationarity_test True
# ('BG', 'STZ') 0.002595777460939682
# hedge_ratio_test 0.7077896912622685
# stationarity_test False
# ('BG', 'CVS') 0.0028780764486469193
# hedge_ratio_test -0.7472819923760283
# stationarity_test False
# ('BG', 'NUE') 0.0002443030425410516
# hedge_ratio_test 0.622251886494544
# stationarity_test False
# ('CPB', 'PFE') 0.010490391592422939
# hedge_ratio_test -2.6882320874083745
# stationarity_test False
# ('CPB', 'SHW') 0.0006676234927902315
# hedge_ratio_test 0.29422144309244397
# stationarity_test False
# ('CDW', 'ECL') 0.06037339465380619
# ('CDW', 'FI') 0.022966117683592174
# hedge_ratio_test 1.449962123328147
# stationarity_test False
# ('CDW', 'FTV') 0.020878491581836987
# hedge_ratio_test 3.8460838611503707
# stationarity_test True
# ('CDW', 'HLT') 0.008760968373418856
# hedge_ratio_test 0.6845732010780905
# stationarity_test False
# ('CDW', 'HWM') 0.019044652020339736
# hedge_ratio_test 3.333670253590532
# stationarity_test False
# ('CDW', 'LMT') 0.3320044719958416
# ('CDW', 'OTIS') 0.000564418097878665
# hedge_ratio_test 2.4870102100554745
# stationarity_test False
# ('CDW', 'PFG') 0.19755596212807675
# ('CDW', 'PRU') 0.10850798324816202
# ('CDW', 'V') 0.11525052543131831
# ('CDW', 'WFC') 0.04064431991161802
# hedge_ratio_test 2.7699122049435285
# stationarity_test False
# ('CHD', 'KMB') 0.006655076121698999
# hedge_ratio_test 0.8193993945986167
# stationarity_test False
# ('C', 'L') 0.0028727833202523713
# hedge_ratio_test -0.95993336403878
# stationarity_test False
# ('C', 'PFE') 0.004253032082345895
# hedge_ratio_test -1.5239543954148784
# stationarity_test False
# ('C', 'WRB') 0.01233917090356146
# hedge_ratio_test -0.6725450140705391
# stationarity_test False
# ('CFG', 'CL') 0.0036453975389242246
# hedge_ratio_test -0.7478094285665147
# stationarity_test False
# ('CFG', 'STZ') 0.0015906098227335497
# hedge_ratio_test -0.1807939466601583
# stationarity_test False
# ('CFG', 'DD') 0.001903975341033643
# hedge_ratio_test -0.6510805177324381
# stationarity_test False
# ('CFG', 'ETN') 0.010230678872051289
# hedge_ratio_test 0.035412225149157005
# stationarity_test False
# ('CFG', 'ELV') 0.030114261720924507
# hedge_ratio_test -0.09150866386127327
# stationarity_test False
# ('CFG', 'GE') 0.012167096675711057
# hedge_ratio_test -0.28896831758295655
# stationarity_test False
# ('CFG', 'HWM') 0.00253715250599977
# hedge_ratio_test 0.1216373235656606
# stationarity_test False
# ('CFG', 'JNJ') 0.00019293269540106292
# hedge_ratio_test -0.13940199184118718
# stationarity_test False
# ('CFG', 'KMB') 0.001367538388923325
# hedge_ratio_test -0.4379983225499678
# stationarity_test False
# ('CFG', 'LMT') 0.08573008556529838
# ('CFG', 'MMC') 0.4737176731920108
# ('CFG', 'MDLZ') 0.019955532865459834
# hedge_ratio_test 0.6518991432736836
# stationarity_test False
# ('CFG', 'NDAQ') 0.00467040353139673
# hedge_ratio_test -0.3960392392620782
# stationarity_test False
# ('CFG', 'NSC') 0.0005804312292145223
# hedge_ratio_test -0.0879304397980082
# stationarity_test False
# ('CFG', 'NUE') 0.008685730347473228
# hedge_ratio_test -0.14794308093933706
# stationarity_test False
# ('CFG', 'PEP') 0.006785224615980238
# hedge_ratio_test -0.35041718984352355
# stationarity_test True
# ('CFG', 'PFE') 9.981053744810881e-05
# hedge_ratio_test -0.5695206076214627
# stationarity_test False
# ('CFG', 'PG') 0.001050880430483359
# hedge_ratio_test -0.17860712259563555
# stationarity_test False
# ('CFG', 'RSG') 0.29625672550811444
# ('CFG', 'SPGI') 0.00879813432683178
# hedge_ratio_test -0.10844315221782819
# stationarity_test False
# ('CFG', 'STLD') 0.0058763271534210525
# hedge_ratio_test -0.1646071274671146
# stationarity_test False
# ('CFG', 'TXT') 0.005675305642570371
# hedge_ratio_test -0.5595305681670955
# stationarity_test False
# ('CFG', 'VZ') 0.008960571657862588
# hedge_ratio_test -0.20092276658093555
# stationarity_test False
# ('CFG', 'WRB') 0.005854477437913575
# hedge_ratio_test -0.3089848582798458
# stationarity_test False
# ('KO', 'FTV') 0.194921686241664
# ('KO', 'MCD') 0.05460044605582961
# ('KO', 'XYL') 0.8358477408658754
# ('CTSH', 'LMT') 0.2359945361938509
# ('CMA', 'DD') 0.0017390549622087166
# hedge_ratio_test -0.5873600623091959
# stationarity_test False
# ('CMA', 'ETN') 0.0012842046974677586
# hedge_ratio_test 0.1434367486615683
# stationarity_test False
# ('CMA', 'ECL') 0.0014089568253803533
# hedge_ratio_test 0.2794978775566447
# stationarity_test False
# ('CMA', 'ELV') 0.006530191222409818
# hedge_ratio_test -0.19736355733983868
# stationarity_test False
# ('CMA', 'FDX') 0.03679250995159534
# hedge_ratio_test 0.22057610760480897
# stationarity_test False
# ('CMA', 'FI') 0.005424348818217625
# hedge_ratio_test 0.5382273566922622
# stationarity_test False
# ('CMA', 'FTV') 0.145259162561572
# ('CMA', 'HLT') 0.04598694007215248
# hedge_ratio_test 0.23909004871369852
# stationarity_test False
# ('CMA', 'HWM') 0.00829817944999354
# hedge_ratio_test 0.8881865219607968
# stationarity_test False
# ('CMA', 'IR') 0.00957160921190294
# hedge_ratio_test 0.7391275919542597
# stationarity_test False
# ('CMA', 'JNJ') 0.005094855823533392
# hedge_ratio_test -0.16194048837724348
# stationarity_test False
# ('CMA', 'KDP') 0.01956488350787166
# hedge_ratio_test 3.410006957061077
# stationarity_test False
# ('CMA', 'LW') 0.02695311512679611
# hedge_ratio_test 0.6692170155784861
# stationarity_test False
# ('CMA', 'LMT') 0.002357963337315063
# hedge_ratio_test 0.1091452019743081
# stationarity_test False
# ('CMA', 'L') 0.009115315929535931
# hedge_ratio_test -0.5563390711478007
# stationarity_test False
# ('CMA', 'MAR') 0.031255177051945866
# hedge_ratio_test 0.19171906197316513
# stationarity_test False
# ('CMA', 'MA') 0.01696467668124547
# hedge_ratio_test -0.010882037157437283
# stationarity_test False
# ('CMA', 'MET') 0.13942824147638294
# ('CMA', 'MDLZ') 0.005405641562423772
# hedge_ratio_test 1.5179106710861707
# stationarity_test False
# ('CMA', 'NDAQ') 0.0016783780484381967
# hedge_ratio_test -0.6497230172640621
# stationarity_test False
# ('CMA', 'NSC') 0.003418656446004639
# hedge_ratio_test -0.07574327837229225
# stationarity_test False
# ('CMA', 'NUE') 0.00856429316451285
# hedge_ratio_test -0.14724260624040586
# stationarity_test False
# ('CMA', 'OTIS') 0.409739421260545
# ('CMA', 'PEP') 0.00818538731339737
# hedge_ratio_test -0.3900787701206325
# stationarity_test False
# ('CMA', 'PFE') 0.0009193672978712341
# hedge_ratio_test -0.48840093492327874
# stationarity_test False
# ('CMA', 'PPG') 0.0046941027375078884
# hedge_ratio_test 0.5954551605516694
# stationarity_test False
# ('CMA', 'PFG') 0.7232382502764734
# ('CMA', 'PRU') 0.05331962832261367
# ('CMA', 'RJF') 0.006204613397427617
# hedge_ratio_test 0.13524466061132498
# stationarity_test False
# ('CMA', 'RTX') 0.0032409603658873614
# hedge_ratio_test -0.45186829251132027
# stationarity_test False
# ('CMA', 'SBUX') 0.02912576745413175
# hedge_ratio_test -0.1295565005569745
# stationarity_test False
# ('CMA', 'STT') 0.009841776716925071
# hedge_ratio_test 0.35588733978365245
# stationarity_test False
# ('CMA', 'STLD') 0.006690687152538199
# hedge_ratio_test -0.1564305883967422
# stationarity_test False
# ('CMA', 'UNH') 0.00032732035786409516
# hedge_ratio_test -0.24513747776902756
# stationarity_test False
# ('CMA', 'VZ') 0.0026270360425252205
# hedge_ratio_test -1.7058602368218698
# stationarity_test False
# ('CMA', 'V') 0.008992381658744265
# hedge_ratio_test 0.23205790600859647
# stationarity_test False
# ('CMA', 'WFC') 0.10471541539183021
# ('CAG', 'DD') 0.00928792257281606
# hedge_ratio_test -0.7008805764341143
# stationarity_test True
# ('CAG', 'NUE') 0.0040279653845681105
# hedge_ratio_test -0.1387896948973864
# stationarity_test False
# ('CAG', 'PFE') 0.011242465661068034
# hedge_ratio_test -0.8155357741867705
# stationarity_test False
# ('CAG', 'STLD') 0.009852924905200169
# hedge_ratio_test -0.1681315622271571
# stationarity_test False
# ('STZ', 'CVS') 1.6696846474565433e-06
# hedge_ratio_test -0.9829817975019592
# stationarity_test True
# ('STZ', 'NUE') 0.002047480470045283
# hedge_ratio_test 0.7585922145871016
# stationarity_test False
# ('STZ', 'PFE') 0.004466204123969931
# hedge_ratio_test 5.1323392900486144
# stationarity_test True
# ('STZ', 'STLD') 0.0027365285258288356
# hedge_ratio_test 0.9515712315963273
# stationarity_test False
# ('CSGP', 'TXT') 0.001158326172414928
# hedge_ratio_test 1.329838687277712
# stationarity_test False
# ('CSGP', 'UPS') 0.006470892982860541
# hedge_ratio_test -0.5047275359751638
# stationarity_test False
# ('CSGP', 'WRB') 0.006840263651841348
# hedge_ratio_test 0.8320311292483054
# stationarity_test False
# ('CSX', 'CVS') 0.0014556726084407141
# hedge_ratio_test -0.001296844122658864
# stationarity_test True
# ('CSX', 'DD') 0.001308726671490498
# hedge_ratio_test -0.13063459376090636
# stationarity_test True
# ('CSX', 'ETN') 3.812212478596791e-05
# hedge_ratio_test -0.03999173096220507
# stationarity_test False
# ('CSX', 'ECL') 0.0007858063707861286
# hedge_ratio_test -0.023794217291190217
# stationarity_test True
# ('CSX', 'EA') 0.0007385775808907071
# hedge_ratio_test -0.12279282965394098
# stationarity_test False
# ('CSX', 'ELV') 0.001538264011826534
# hedge_ratio_test -0.005501444374414938
# stationarity_test False
# ('CSX', 'FAST') 0.0038432918063572054
# hedge_ratio_test 0.01770813198183041
# stationarity_test True
# ('CSX', 'FDX') 0.0008181873681940221
# hedge_ratio_test -0.0032115752784546425
# stationarity_test True
# ('CSX', 'FITB') 0.005863600093250964
# hedge_ratio_test 0.061605601285916245
# stationarity_test True
# ('CSX', 'FI') 9.79808567380494e-05
# hedge_ratio_test -0.06745518829546934
# stationarity_test True
# ('CSX', 'FTV') 0.016123890504029927
# hedge_ratio_test 0.08334717871803898
# stationarity_test True
# ('CSX', 'GRMN') 0.03484524983028568
# hedge_ratio_test 0.09099730935747363
# stationarity_test False
# ('CSX', 'GE') 0.0009702830260822934
# hedge_ratio_test -0.053076642759540583
# stationarity_test False
# ('CSX', 'GD') 0.019014645096210443
# hedge_ratio_test 0.040890167628295004
# stationarity_test False
# ('CSX', 'GIS') 0.020410247860404053
# hedge_ratio_test 0.10987217037998195
# stationarity_test False
# ('CSX', 'GPC') 0.009095275385922067
# hedge_ratio_test 0.12634199111289227
# stationarity_test False
# ('CSX', 'GL') 0.003360524660158326
# hedge_ratio_test 0.0733064874136033
# stationarity_test False
# ('CSX', 'GS') 0.0011096375640167252
# hedge_ratio_test -0.0026627735739738825
# stationarity_test True
# ('CSX', 'HIG') 0.0016822803365521043
# hedge_ratio_test 0.002646423281233934
# stationarity_test True
# ('CSX', 'HLT') 0.0008977801350324093
# hedge_ratio_test -0.005134837087352739
# stationarity_test True
# ('CSX', 'HON') 0.6282440167894272
# ('CSX', 'HWM') 0.0002582429894003967
# hedge_ratio_test -0.29247554733234066
# stationarity_test False
# ('CSX', 'HBAN') 0.009139694366963116
# hedge_ratio_test 0.24957924339180293
# stationarity_test True
# ('CSX', 'IBM') 0.041212693111510434
# hedge_ratio_test 0.04709938643304129
# stationarity_test False
# ('CSX', 'ITW') 0.004002197760645942
# hedge_ratio_test 0.00808338378182892
# stationarity_test True
# ('CSX', 'IR') 1.9857391673927622e-05
# hedge_ratio_test -0.15884472536428845
# stationarity_test False
# ('CSX', 'ICE') 0.006732286641976158
# hedge_ratio_test 0.028136804677840688
# stationarity_test True
# ('CSX', 'IPG') 0.010972484551167819
# hedge_ratio_test 0.22471851194535875
# stationarity_test False
# ('CSX', 'JNJ') 0.0001815794746242984
# hedge_ratio_test 0.06124052630984903
# stationarity_test False
# ('CSX', 'JCI') 0.0013373106091339574
# hedge_ratio_test -0.008127860043034438
# stationarity_test True
# ('CSX', 'JPM') 0.0032260378102717193
# hedge_ratio_test -0.11924607211193103
# stationarity_test False
# ('CSX', 'KDP') 0.13854050135383705
# ('CSX', 'KMB') 5.715264843801113e-05
# hedge_ratio_test 0.08408656667451342
# stationarity_test False
# ('CSX', 'KHC') 0.04291286538478486
# hedge_ratio_test 0.1722531552754284
# stationarity_test False
# ('CSX', 'LHX') 0.05220871576242209
# ('CSX', 'LW') 0.210087202607659
# ('CSX', 'LMT') 0.00054656121383483
# hedge_ratio_test -0.044687952535510916
# stationarity_test False
# ('CSX', 'L') 0.00132852291482758
# hedge_ratio_test 0.02879308647965318
# stationarity_test True
# ('CSX', 'MTB') 0.009481960361671486
# hedge_ratio_test 0.13148949601287735
# stationarity_test False
# ('CSX', 'MAR') 0.002401063963762621
# hedge_ratio_test 0.0024395575887805193
# stationarity_test True
# ('CSX', 'MMC') 0.001561630072654929
# hedge_ratio_test -0.006384088070656768
# stationarity_test True
# ('CSX', 'MA') 0.00027102429326928237
# hedge_ratio_test -0.021551182245827853
# stationarity_test False
# ('CSX', 'MKC') 0.01676296436229331
# hedge_ratio_test 0.1031294233041518
# stationarity_test False
# ('CSX', 'MCD') 0.16249484969724604
# ('CSX', 'MRK') 0.001808193145545639
# hedge_ratio_test 0.09039594318617603
# stationarity_test False
# ('CSX', 'MET') 0.0029559127713475073
# hedge_ratio_test 0.029286958317835954
# stationarity_test True
# ('CSX', 'TAP') 0.058362181014569185
# ('CSX', 'MDLZ') 0.011119132958783662
# hedge_ratio_test 0.1833945129596291
# stationarity_test False
# ('CSX', 'MCO') 0.07002308582631575
# ('CSX', 'NDAQ') 0.000484471576860008
# hedge_ratio_test 0.05691508952982449
# stationarity_test True
# ('CSX', 'NSC') 0.007814540933558203
# hedge_ratio_test 0.08594765438974011
# stationarity_test False
# ('CSX', 'NTRS') 0.00326207847475289
# hedge_ratio_test 0.02877774633251641
# stationarity_test True
# ('CSX', 'NUE') 0.0036209459982244024
# hedge_ratio_test -0.009250270568139984
# stationarity_test True
# ('CSX', 'OMC') 0.06913766504090217
# ('CSX', 'ORCL') 0.05033387525127899
# ('CSX', 'OTIS') 0.001104219037628499
# hedge_ratio_test -0.009891078219129545
# stationarity_test True
# ('CSX', 'PCAR') 0.0004737603804039582
# hedge_ratio_test -0.01668373601193858
# stationarity_test True
# ('CSX', 'PAYX') 0.049941098595955066
# hedge_ratio_test 0.06843683118607594
# stationarity_test False
# ('CSX', 'PEP') 0.00024468550338562417
# hedge_ratio_test 0.07888317377400832
# stationarity_test True
# ('CSX', 'PFE') 0.0019925835061779546
# hedge_ratio_test 0.23563015806316162
# stationarity_test False
# ('CSX', 'PM') 0.0017024860836633595
# hedge_ratio_test -0.006899800894701942
# stationarity_test True
# ('CSX', 'PPG') 0.007239829613062063
# hedge_ratio_test 0.03248541271748376
# stationarity_test True
# ('CSX', 'PFG') 0.01955159055710501
# hedge_ratio_test 0.08916393974182824
# stationarity_test False
# ('CSX', 'PG') 0.0008323712495441253
# hedge_ratio_test 0.0059736328489916266
# stationarity_test True
# ('CSX', 'PRU') 0.00047857865834251
# hedge_ratio_test -0.020429704787161634
# stationarity_test True
# ('CSX', 'RJF') 0.0005027325612888983
# hedge_ratio_test -0.09563866560196678
# stationarity_test False
# ('CSX', 'RTX') 0.0016915959655793755
# hedge_ratio_test 0.13110142186527912
# stationarity_test False
# ('CSX', 'RF') 0.008447690401752837
# hedge_ratio_test 0.1659713767704729
# stationarity_test True
# ('CSX', 'RSG') 0.008312855727923502
# hedge_ratio_test 0.049595803855510795
# stationarity_test False
# ('CSX', 'ROL') 0.0033727449138543906
# hedge_ratio_test 0.06133799503302079
# stationarity_test True
# ('CSX', 'SPGI') 0.003365450591095872
# hedge_ratio_test 0.01430643136479396
# stationarity_test False
# ('CSX', 'SHW') 0.0050442802286444835
# hedge_ratio_test 0.007629145982152859
# stationarity_test True
# ('CSX', 'SBUX') 0.001227581667904028
# hedge_ratio_test -0.03497819375013188
# stationarity_test True
# ('CSX', 'STT') 0.0002646081981186356
# hedge_ratio_test -0.07117180262647921
# stationarity_test True
# ('CSX', 'STLD') 0.0016404230637547582
# hedge_ratio_test -0.0002200619230744369
# stationarity_test True
# ('CSX', 'TMUS') 0.0018242601022333041
# hedge_ratio_test 0.001067052640144922
# stationarity_test True
# ('CSX', 'TXT') 0.000773844460745748
# hedge_ratio_test -0.060745247237515024
# stationarity_test True
# ('CSX', 'TRV') 0.04572861294321606
# hedge_ratio_test 0.1072070642069953
# stationarity_test False
# ('CSX', 'TFC') 0.0018619236421728433
# hedge_ratio_test 0.005137807354163443
# stationarity_test True
# ('CSX', 'USB') 0.005413728496612002
# hedge_ratio_test 0.04333128105762024
# stationarity_test True
# ('CSX', 'UNH') 0.08836979385532406
# ('CSX', 'VRSK') 0.0016488384226632695
# hedge_ratio_test -0.006207047132890713
# stationarity_test True
# ('CSX', 'VZ') 0.0004280615972905728
# hedge_ratio_test 0.158553676894159
# stationarity_test True
# ('CSX', 'V') 0.0010548844028375277
# hedge_ratio_test -0.007178206019210154
# stationarity_test True
# ('CSX', 'WRB') 0.0016117779989466756
# hedge_ratio_test 0.03589994555077038
# stationarity_test True
# ('CSX', 'WM') 0.6336914499945379
# ('CSX', 'WFC') 0.00017571571003306133
# hedge_ratio_test -0.09463332183461681
# stationarity_test True
# ('CSX', 'XYL') 0.005614261037054137
# hedge_ratio_test 0.02944768577188195
# stationarity_test True
# ('CVS', 'NUE') 0.012222851420485702
# hedge_ratio_test -0.762026058565582
# stationarity_test False
# ('CVS', 'PFE') 0.00269285280159699
# hedge_ratio_test -5.490773485910902
# stationarity_test True
# ('CVS', 'STLD') 0.0007070830734898113
# hedge_ratio_test -0.9709118465925021
# stationarity_test False
# ('DRI', 'DD') 0.00169148515299801
# hedge_ratio_test -0.9517482186419176
# stationarity_test False
# ('DRI', 'ETN') 0.0437930805567277
# hedge_ratio_test -0.2285393718647208
# stationarity_test True
# ('DRI', 'ECL') 0.006629322702814181
# hedge_ratio_test -0.36412980166665976
# stationarity_test False
# ('DRI', 'EA') 0.0575888524253647
# ('DRI', 'ELV') 0.0015855122024750685
# hedge_ratio_test -0.013428538457150974
# stationarity_test False
# ('DRI', 'FAST') 0.008462144700740186
# hedge_ratio_test 0.33007067579660665
# stationarity_test False
# ('DRI', 'FDX') 0.0014416457461193782
# hedge_ratio_test 0.0032204806507756534
# stationarity_test False
# ('DRI', 'FI') 0.004428742583611404
# hedge_ratio_test -0.3055082092868534
# stationarity_test False
# ('DRI', 'FTV') 0.001374675722672432
# hedge_ratio_test 0.19759533459130374
# stationarity_test False
# ('DRI', 'GE') 0.003476725081172313
# hedge_ratio_test -0.39801107049179535
# stationarity_test False
# ('DRI', 'GPC') 0.006806674588282004
# hedge_ratio_test 0.7260552955047537
# stationarity_test True
# ('DRI', 'GL') 0.0036233026947104395
# hedge_ratio_test 0.3011332389033977
# stationarity_test False
# ('DRI', 'GS') 0.0005737665044112986
# hedge_ratio_test -0.09250311456988217
# stationarity_test False
# ('DRI', 'HIG') 0.006352515603823935
# hedge_ratio_test 0.854409660467546
# stationarity_test False
# ('DRI', 'HLT') 0.004150339043168417
# hedge_ratio_test -0.12458425463695594
# stationarity_test False
# ('DRI', 'HON') 0.05236620660840182
# ('DRI', 'HWM') 0.11185698331147953
# ('DRI', 'IBM') 0.04315434660716243
# hedge_ratio_test 0.32226641705847503
# stationarity_test False
# ('DRI', 'IR') 0.02230462984824832
# hedge_ratio_test -0.7201378202540563
# stationarity_test True
# ('DRI', 'ICE') 0.0013048651954953908
# hedge_ratio_test 0.01835742089396941
# stationarity_test False
# ('DRI', 'IPG') 0.007106369861830119
# hedge_ratio_test 0.8881424856162099
# stationarity_test False
# ('DRI', 'JNJ') 0.005813624344635231
# hedge_ratio_test 0.2510826548301692
# stationarity_test False
# ('DRI', 'JCI') 0.008493998554995542
# hedge_ratio_test 0.18807265495390346
# stationarity_test False
# ('DRI', 'JPM') 0.0018542303795718803
# hedge_ratio_test -0.34680766274899755
# stationarity_test True
# ('DRI', 'KDP') 0.008005245161067646
# hedge_ratio_test 1.6330245932926157
# stationarity_test False
# ('DRI', 'KMB') 0.0011988333935055615
# hedge_ratio_test 0.018371581538879106
# stationarity_test False
# ('DRI', 'KHC') 0.07605031776188666
# ('DRI', 'LW') 0.021296035061854464
# hedge_ratio_test 0.6454634950553039
# stationarity_test False
# ('DRI', 'LMT') 0.0161702596300442
# hedge_ratio_test -0.2905392102100684
# stationarity_test False
# ('DRI', 'L') 0.0010871108316450261
# hedge_ratio_test 0.09379298074692625
# stationarity_test False
# ('DRI', 'MAR') 0.003191420099216466
# hedge_ratio_test -0.06592159951906679
# stationarity_test False
# ('DRI', 'MMC') 0.03844643309779482
# hedge_ratio_test -0.27885753262803786
# stationarity_test False
# ('DRI', 'MA') 0.012971889011856244
# hedge_ratio_test -0.15660373849127596
# stationarity_test False
# ('DRI', 'MRK') 0.0015601586882180855
# hedge_ratio_test 0.729606867566537
# stationarity_test False
# ('DRI', 'MET') 0.0021892186473169302
# hedge_ratio_test 0.265221167949103
# stationarity_test False
# ('DRI', 'TAP') 0.0021503958768353073
# hedge_ratio_test 0.2684359721657428
# stationarity_test False
# ('DRI', 'MDLZ') 0.001710687419158879
# hedge_ratio_test 0.703128373564377
# stationarity_test False
# ('DRI', 'NDAQ') 0.003375664656479712
# hedge_ratio_test 0.25456082305815264
# stationarity_test False
# ('DRI', 'NSC') 0.06711033339622587
# ('DRI', 'OMC') 0.038382482648616455
# hedge_ratio_test 0.5365150761426267
# stationarity_test False
# ('DRI', 'ORCL') 0.3891995120943763
# ('DRI', 'OTIS') 0.0011051755007376114
# hedge_ratio_test -0.199355301800914
# stationarity_test False
# ('DRI', 'PCAR') 0.008165961344428995
# hedge_ratio_test 0.163189097669446
# stationarity_test False
# ('DRI', 'PEP') 0.0002776540199780587
# hedge_ratio_test 0.25355170439855357
# stationarity_test False
# ('DRI', 'PFE') 0.017671242782736955
# hedge_ratio_test 0.9308409303478735
# stationarity_test False
# ('DRI', 'PM') 0.003560992371391239
# hedge_ratio_test -0.31926011296408596
# stationarity_test False
# ('DRI', 'PPG') 0.0073091489093110185
# hedge_ratio_test 0.1488768225403022
# stationarity_test False
# ('DRI', 'PFG') 0.02199008545352292
# hedge_ratio_test 0.7640191284813191
# stationarity_test False
# ('DRI', 'PRU') 0.001302928364400258
# hedge_ratio_test -0.0036569287172002474
# stationarity_test False
# ('DRI', 'RJF') 0.05236842859965942
# ('DRI', 'RTX') 0.04415792726114281
# hedge_ratio_test 0.976345776589771
# stationarity_test False
# ('DRI', 'RF') 0.0013903974279461289
# hedge_ratio_test 0.018691749399420754
# stationarity_test False
# ('DRI', 'RSG') 0.01290822937516542
# hedge_ratio_test -0.22853817430645554
# stationarity_test False
# ('DRI', 'ROL') 0.006484997667131082
# hedge_ratio_test 1.010209309467753
# stationarity_test False
# ('DRI', 'SPGI') 0.0031915301993426745
# hedge_ratio_test 0.05557846978026336
# stationarity_test False
# ('DRI', 'SBUX') 0.012991067697631588
# hedge_ratio_test -0.4060335181950352
# stationarity_test False
# ('DRI', 'STT') 0.005099169871396228
# hedge_ratio_test -0.7293711588180048
# stationarity_test True
# ('DRI', 'STLD') 0.004737840810407256
# hedge_ratio_test -0.10472971721750718
# stationarity_test False
# ('DRI', 'TXT') 0.0037278068804324827
# hedge_ratio_test -0.415980417636172
# stationarity_test False
# ('DRI', 'TFC') 0.0040334585108355685
# hedge_ratio_test 0.24118777641865563
# stationarity_test False
# ('DRI', 'UNH') 0.003587269898560115
# hedge_ratio_test -0.06329074203968299
# stationarity_test False
# ('DRI', 'VRSK') 0.007265207245691957
# hedge_ratio_test -0.08746143694029059
# stationarity_test False
# ('DRI', 'VZ') 0.022327534802189086
# hedge_ratio_test 1.3247860162382437
# stationarity_test False
# ('DRI', 'V') 0.004833894451362293
# hedge_ratio_test -0.25301954132476623
# stationarity_test False
# ('DRI', 'WRB') 0.003544443113755901
# hedge_ratio_test 0.08072194912877373
# stationarity_test False
# ('DRI', 'WFC') 0.005120730493713398
# hedge_ratio_test -0.7073198090138338
# stationarity_test True
# ('DD', 'GIS') 0.00908537542820922
# hedge_ratio_test -0.44811506485415215
# stationarity_test True
# ('DD', 'MKC') 0.0007314201555899112
# hedge_ratio_test -0.4304055166332137
# stationarity_test False
# ('DD', 'MCO') 0.004821236991135426
# hedge_ratio_test -0.1344512809437642
# stationarity_test True
# ('DD', 'NUE') 0.00496370401811853
# hedge_ratio_test 0.12948392331006386
# stationarity_test False
# ('DD', 'PNC') 0.007082891606665487
# hedge_ratio_test -0.20119764344663632
# stationarity_test False
# ('DD', 'UPS') 0.0017814302730946932
# hedge_ratio_test -0.23826396784171988
# stationarity_test False
# ('ETN', 'FI') 0.01085602414311763
# hedge_ratio_test 2.1724286605609073
# stationarity_test False
# ('ETN', 'WFC') 0.03133415612798185
# hedge_ratio_test 4.373313579656207
# stationarity_test False
# ('ECL', 'HLT') 0.006165638966109529
# hedge_ratio_test 0.35415552061206756
# stationarity_test False
# ('ECL', 'HWM') 0.007396753234653566
# hedge_ratio_test 1.905475072380812
# stationarity_test False
# ('ECL', 'LMT') 0.03898539269881908
# hedge_ratio_test 0.46103926120545413
# stationarity_test False
# ('ECL', 'MA') 0.012230825631482199
# hedge_ratio_test 0.28990696148802036
# stationarity_test False
# ('ECL', 'V') 0.0060094413932400975
# hedge_ratio_test 0.7828631992279814
# stationarity_test False
# ('EA', 'IBM') 0.6116516975498869
# ('EA', 'JPM') 0.21136051516403814
# ('EA', 'LMT') 0.13829579680253534
# ('EA', 'RJF') 0.1277224408991312
# ('EA', 'VZ') 0.0785520469828699
# ('FAST', 'PFE') 0.008615831132568367
# hedge_ratio_test -2.219750679390938
# stationarity_test False
# ('FAST', 'TMUS') 0.01939228740278546
# hedge_ratio_test 0.46418090507714255
# stationarity_test False
# ('FDX', 'FI') 0.0061368335665401615
# hedge_ratio_test 2.7984816589242776
# stationarity_test False
# ('FDX', 'NSC') 0.042135109416113724
# hedge_ratio_test -0.817029119133988
# stationarity_test False
# ('FDX', 'PFE') 0.006778014318516892
# hedge_ratio_test -6.337941023165881
# stationarity_test False
# ('FDX', 'RTX') 0.008549234924006499
# hedge_ratio_test -3.3793919330233613
# stationarity_test False
# ('FDX', 'ROL') 0.00210288319181829
# hedge_ratio_test 11.744901514666068
# stationarity_test False
# ('FDX', 'TMUS') 0.0024534716900059214
# hedge_ratio_test 1.5676477971943688
# stationarity_test False
# ('FDX', 'TFC') 0.03734621611651728
# hedge_ratio_test 6.283366793801168
# stationarity_test False
# ('FDX', 'USB') 0.024003769373686725
# hedge_ratio_test 6.670994522527929
# stationarity_test False
# ('FITB', 'FI') 0.15023752678535007
# ('FITB', 'FTV') 0.2759666192973586
# ('FITB', 'GE') 0.011743285445247154
# hedge_ratio_test -0.15978204218490877
# stationarity_test False
# ('FITB', 'GL') 0.0037535616395788897
# hedge_ratio_test -0.17481572953226426
# stationarity_test False
# ('FITB', 'HWM') 0.02163645282918015
# hedge_ratio_test 0.4639966176214462
# stationarity_test False
# ('FITB', 'IR') 0.17281823396625
# ('FITB', 'JNJ') 0.0011677634576500943
# hedge_ratio_test -0.13433516706709947
# stationarity_test False
# ('FITB', 'JCI') 0.06851868568266203
# ('FITB', 'KMB') 0.006935410065635079
# hedge_ratio_test -0.2158063490521685
# stationarity_test False
# ('FITB', 'LW') 0.01467422650074508
# hedge_ratio_test 0.1366980272389555
# stationarity_test False
# ('FITB', 'LMT') 0.018262877895298273
# hedge_ratio_test 0.013095168431824594
# stationarity_test False
# ('FITB', 'L') 0.000787256579516828
# hedge_ratio_test -0.37475256113952804
# stationarity_test False
# ('FITB', 'MAR') 0.04832981114827794
# hedge_ratio_test 0.06358671648000769
# stationarity_test False
# ('FITB', 'MA') 0.011866915768466223
# hedge_ratio_test 0.015506584978279087
# stationarity_test False
# ('FITB', 'MRK') 0.009188104937697669
# hedge_ratio_test -0.06322195627171073
# stationarity_test False
# ('FITB', 'TAP') 0.030968305673785845
# hedge_ratio_test 0.4367481782826503
# stationarity_test False
# ('FITB', 'NDAQ') 0.0009010749181228451
# hedge_ratio_test -0.35750979612734124
# stationarity_test False
# ('FITB', 'NSC') 0.005403994882849098
# hedge_ratio_test -0.0595636529810334
# stationarity_test False
# ('FITB', 'NUE') 0.008645751429212317
# hedge_ratio_test -0.08583553089885934
# stationarity_test False
# ('FITB', 'OTIS') 0.8138607189980571
# ('FITB', 'PCAR') 0.44547939240105294
# ('FITB', 'PEP') 0.00042780622567699996
# hedge_ratio_test -0.275423447633832
# stationarity_test False
# ('FITB', 'PFE') 5.300837322164925e-05
# hedge_ratio_test -0.5450191303567964
# stationarity_test False
# ('FITB', 'PG') 0.011718940165294709
# hedge_ratio_test -0.09973001295532166
# stationarity_test False
# ('FITB', 'RTX') 0.0030477785583237684
# hedge_ratio_test -0.2985340484771578
# stationarity_test False
# ('FITB', 'SPGI') 0.016352648636456062
# hedge_ratio_test -0.09126885953377434
# stationarity_test True
# ('FITB', 'STLD') 0.006192613302139062
# hedge_ratio_test -0.10115653258391868
# stationarity_test False
# ('FITB', 'TXT') 0.008016176354901353
# hedge_ratio_test -0.3448582173109743
# stationarity_test False
# ('FITB', 'WRB') 0.0007936611065687602
# hedge_ratio_test -0.25478081806443115
# stationarity_test False
# ('FI', 'IR') 0.013134013997829565
# hedge_ratio_test 1.286933086199585
# stationarity_test False
# ('FI', 'PRU') 0.0360774509366579
# hedge_ratio_test 0.7206305660300785
# stationarity_test False
# ('FTV', 'LMT') 0.6814724522191287
# ('FTV', 'VZ') 0.5493245609683136
# ('GRMN', 'PNC') 0.027495731930220885
# hedge_ratio_test 0.48300342421324
# stationarity_test False
# ('GD', 'MCO') 0.0010583374869681454
# hedge_ratio_test 0.562189533572627
# stationarity_test False
# ('GD', 'PFE') 0.01929094876013675
# hedge_ratio_test -1.355566017541383
# stationarity_test False
# ('GD', 'PNC') 0.019767209986395667
# hedge_ratio_test 0.9515150920037316
# stationarity_test False
# ('GPC', 'GL') 0.008604572495074101
# hedge_ratio_test 0.42021276259630114
# stationarity_test False
# ('GPC', 'HIG') 0.010038171022349315
# hedge_ratio_test 0.19338398624055042
# stationarity_test False
# ('GPC', 'KDP') 0.014377234101481562
# hedge_ratio_test 0.5418517356095753
# stationarity_test False
# ('GPC', 'KMB') 0.00382062394169417
# hedge_ratio_test 0.2907771713403049
# stationarity_test False
# ('GPC', 'LMT') 0.009984088896004223
# hedge_ratio_test 0.14144061077505993
# stationarity_test False
# ('GPC', 'L') 0.005707162797875103
# hedge_ratio_test 0.3283711496225622
# stationarity_test False
# ('GPC', 'MET') 0.01575528797905726
# hedge_ratio_test 0.38507659577908004
# stationarity_test False
# ('GPC', 'NSC') 0.03552889430177508
# hedge_ratio_test 0.32491110815911617
# stationarity_test False
# ('GPC', 'PEP') 0.0037243411803881328
# hedge_ratio_test 0.311521172833803
# stationarity_test False
# ('GPC', 'PFE') 0.01892027618702706
# hedge_ratio_test 1.1685561644962348
# stationarity_test False
# ('GPC', 'PPG') 0.035134887407006835
# hedge_ratio_test 0.04382342792136806
# stationarity_test False
# ('GPC', 'RTX') 0.02630653061895122
# hedge_ratio_test 0.9035021093321961
# stationarity_test False
# ('GPC', 'ROL') 0.013144501603038697
# hedge_ratio_test 0.2951242339481639
# stationarity_test False
# ('GPC', 'SPGI') 0.01212430147618858
# hedge_ratio_test 0.12419307183896772
# stationarity_test False
# ('GPC', 'TXT') 0.0076818789716200635
# hedge_ratio_test 0.30510388698227575
# stationarity_test False
# ('GPC', 'TRV') 0.013784105494918309
# hedge_ratio_test 0.31736714728521626
# stationarity_test False
# ('GS', 'HLT') 0.010501429391762789
# hedge_ratio_test 1.0952467671482238
# stationarity_test False
# ('GS', 'MAR') 0.0029614579961540544
# hedge_ratio_test 0.8359972910010597
# stationarity_test False
# ('HLT', 'HWM') 0.05573550636480187
# ('HLT', 'LMT') 0.31256576513001977
# ('HLT', 'MAR') 0.2627828555206986
# ('HWM', 'IR') 0.01658358716627177
# hedge_ratio_test 0.5143558922233314
# stationarity_test False
# ('HWM', 'LMT') 0.3651428067393506
# ('HBAN', 'IR') 0.022119064192086476
# hedge_ratio_test 0.11568176749347707
# stationarity_test False
# ('HBAN', 'ICE') 0.011438532353872764
# hedge_ratio_test -0.01586946196393057
# stationarity_test False
# ('HBAN', 'JNJ') 0.0002209423973828039
# hedge_ratio_test -0.04602037087122013
# stationarity_test False
# ('HBAN', 'KMB') 0.006945880736969524
# hedge_ratio_test -0.07949277313580157
# stationarity_test False
# ('HBAN', 'LMT') 0.007124265613996979
# hedge_ratio_test 0.000722669557920573
# stationarity_test False
# ('HBAN', 'L') 0.002372218887597451
# hedge_ratio_test -0.1295176197104093
# stationarity_test False
# ('HBAN', 'MMC') 0.2082825532781611
# ('HBAN', 'MA') 0.006535670048005947
# hedge_ratio_test 0.0009933289576566137
# stationarity_test False
# ('HBAN', 'MRK') 0.005799018198871972
# hedge_ratio_test -0.006022888146458388
# stationarity_test False
# ('HBAN', 'MDLZ') 0.0027200099278068567
# hedge_ratio_test 0.23975108214587387
# stationarity_test False
# ('HBAN', 'NDAQ') 0.0002202157735591393
# hedge_ratio_test -0.1265173329098303
# stationarity_test False
# ('HBAN', 'NSC') 0.00026862706006791496
# hedge_ratio_test -0.019543613027737113
# stationarity_test False
# ('HBAN', 'NUE') 0.011769332068328468
# hedge_ratio_test -0.033980547159946445
# stationarity_test False
# ('HBAN', 'ORCL') 0.735529832210554
# ('HBAN', 'PEP') 0.0017325757860007275
# hedge_ratio_test -0.09450565695102184
# stationarity_test False
# ('HBAN', 'PFE') 5.232961493327162e-05
# hedge_ratio_test -0.19675766061722136
# stationarity_test False
# ('HBAN', 'PM') 0.015564909398672484
# hedge_ratio_test -0.07290332588133211
# stationarity_test False
# ('HBAN', 'PG') 0.005141734463968461
# hedge_ratio_test -0.0379140755025516
# stationarity_test False
# ('HBAN', 'PRU') 0.32698809635569825
# ('HBAN', 'RJF') 0.008203514088327063
# hedge_ratio_test -0.003037922589651555
# stationarity_test False
# ('HBAN', 'RTX') 0.00046969898439821285
# hedge_ratio_test -0.09373467673959189
# stationarity_test False
# ('HBAN', 'RSG') 0.062232063216920014
# ('HBAN', 'ROL') 0.15970267969794216
# ('HBAN', 'SPGI') 0.0759165871670308
# ('HBAN', 'SBUX') 0.016262858272935027
# hedge_ratio_test -0.03542571220924878
# stationarity_test False
# ('HBAN', 'STT') 0.007119268476818605
# hedge_ratio_test 0.0014524255851163376
# stationarity_test False
# ('HBAN', 'STLD') 0.0031050126678335366
# hedge_ratio_test -0.03963988954853945
# stationarity_test False
# ('HBAN', 'TMUS') 0.270609004871725
# ('HBAN', 'TXT') 0.011412511843720384
# hedge_ratio_test -0.1428180603797281
# stationarity_test False
# ('HBAN', 'TFC') 0.014178068840939743
# hedge_ratio_test 0.2690162130268741
# stationarity_test False
# ('HBAN', 'UNH') 0.00864808544966386
# hedge_ratio_test -0.028711136694141024
# stationarity_test False
# ('HBAN', 'VZ') 0.006371066185736176
# hedge_ratio_test -0.16240409910065706
# stationarity_test False
# ('HBAN', 'V') 0.006937090640633302
# hedge_ratio_test 0.023995888153962884
# stationarity_test False
# ('HBAN', 'WRB') 0.002569786825996326
# hedge_ratio_test -0.08858689930254811
# stationarity_test False
# ('HBAN', 'WM') 0.002596819749312206
# hedge_ratio_test -0.042279344123698825
# stationarity_test False
# ('IBM', 'JPM') 0.017803344645813825
# hedge_ratio_test 0.872979646878911
# stationarity_test False
# ('IBM', 'LMT') 0.5577656591150515
# ('IBM', 'MMC') 0.5612551417758077
# ('IBM', 'MCD') 0.1109710048581874
# ('IBM', 'TAP') 0.12262417740262177
# ('IBM', 'PFG') 0.13373253124844836
# ('IBM', 'VZ') 0.020001410668099903
# hedge_ratio_test -2.0922976495900887
# stationarity_test False
# ('ITW', 'ROL') 1.6790819029263169e-06
# hedge_ratio_test 6.382865007258246
# stationarity_test False
# ('ITW', 'TMUS') 0.00015501262025861034
# hedge_ratio_test 0.8192497992700674
# stationarity_test True
# ('JNJ', 'PFE') 0.013090174876790706
# hedge_ratio_test 4.604478514342492
# stationarity_test True
# ('JNJ', 'TFC') 0.015252047206927386
# hedge_ratio_test -2.1611801397493346
# stationarity_test False
# ('JCI', 'SPGI') 0.023718138916613493
# hedge_ratio_test -0.263820328684068
# stationarity_test False
# ('JPM', 'VZ') 0.13074004501732384
# ('JPM', 'XYL') 0.5588032785235603
# ('KDP', 'PAYX') 0.0132071783000207
# hedge_ratio_test 0.20500133224284142
# stationarity_test False
# ('KDP', 'PFE') 0.15793162930437082
# ('KDP', 'PFG') 0.06125906764685907
# ('KEY', 'KMB') 0.0008803738615114267
# hedge_ratio_test -0.011866122746233727
# stationarity_test False
# ('KEY', 'KHC') 0.12690022485663305
# ('KEY', 'LHX') 0.006483991420400352
# hedge_ratio_test 0.028884999890645715
# stationarity_test False
# ('KEY', 'LW') 0.07614973937731931
# ('KEY', 'LMT') 0.0015909811671684698
# hedge_ratio_test 0.00928722051331568
# stationarity_test False
# ('KEY', 'L') 0.0005010161341521534
# hedge_ratio_test -0.047983768969398904
# stationarity_test False
# ('KEY', 'MAR') 0.032390822147099055
# hedge_ratio_test 0.02362001217250994
# stationarity_test False
# ('KEY', 'MMC') 0.00031392327603946773
# hedge_ratio_test -0.02394209055233111
# stationarity_test False
# ('KEY', 'MA') 0.0006450683230444493
# hedge_ratio_test -0.0056329693190398985
# stationarity_test False
# ('KEY', 'MKC') 0.006866949179211962
# hedge_ratio_test 0.09303735341527847
# stationarity_test False
# ('KEY', 'MCD') 0.024658647904099815
# hedge_ratio_test 0.045017491999259696
# stationarity_test False
# ('KEY', 'MRK') 0.0011621289227196387
# hedge_ratio_test 0.022188087103710164
# stationarity_test False
# ('KEY', 'MET') 0.0318432914333359
# hedge_ratio_test 0.18350575457412277
# stationarity_test False
# ('KEY', 'TAP') 0.06870748577377826
# ('KEY', 'MDLZ') 0.016298145022681832
# hedge_ratio_test 0.18735892565238002
# stationarity_test False
# ('KEY', 'MCO') 0.19609497305889007
# ('KEY', 'NDAQ') 0.0011468055076202124
# hedge_ratio_test -0.03063515844089571
# stationarity_test False
# ('KEY', 'NSC') 0.0011689044342299696
# hedge_ratio_test 0.015443209304244095
# stationarity_test False
# ('KEY', 'NTRS') 0.004795224195594786
# hedge_ratio_test 0.1405235451950369
# stationarity_test False
# ('KEY', 'NUE') 0.0013540770911328137
# hedge_ratio_test -0.017603547450921027
# stationarity_test False
# ('KEY', 'OMC') 0.20141766979923237
# ('KEY', 'ORCL') 0.05336488593457749
# ('KEY', 'OTIS') 0.23931498920717909
# ('KEY', 'PCAR') 0.03183837087673748
# hedge_ratio_test 0.04821171860346349
# stationarity_test False
# ('KEY', 'PAYX') 0.07755817420795345
# ('KEY', 'PEP') 0.0006074435649415703
# hedge_ratio_test -0.03688295721957399
# stationarity_test False
# ('KEY', 'PFE') 0.0009196924581590279
# hedge_ratio_test 0.03946871257666598
# stationarity_test False
# ('KEY', 'PM') 0.0009254236447851249
# hedge_ratio_test -0.03203064645794817
# stationarity_test False
# ('KEY', 'PPG') 0.06059882552650367
# ('KEY', 'PFG') 0.5284648038069638
# ('KEY', 'PG') 0.001966215615776986
# hedge_ratio_test -0.015099051731151563
# stationarity_test False
# ('KEY', 'PRU') 0.05787980818913456
# ('KEY', 'RJF') 0.002123344053575709
# hedge_ratio_test 0.01910696363749713
# stationarity_test False
# ('KEY', 'RTX') 0.0009041525234119934
# hedge_ratio_test 0.010358962226676274
# stationarity_test False
# ('KEY', 'RSG') 0.0007884031750887394
# hedge_ratio_test -0.003223338459727259
# stationarity_test False
# ('KEY', 'ROL') 0.07405548037388522
# ('KEY', 'SPGI') 0.0003455451804442122
# hedge_ratio_test -0.008199900610192554
# stationarity_test False
# ('KEY', 'SHW') 0.019131342683920145
# hedge_ratio_test 0.01721275119244022
# stationarity_test False
# ('KEY', 'SBUX') 0.000896953209325956
# hedge_ratio_test -0.009810171876494425
# stationarity_test False
# ('KEY', 'STT') 0.0020868560552430144
# hedge_ratio_test 0.02928348662215352
# stationarity_test False
# ('KEY', 'STLD') 0.0012950601025411431
# hedge_ratio_test -0.013630583895337584
# stationarity_test False
# ('KEY', 'TMUS') 0.0371924655390781
# hedge_ratio_test 0.03383733657670153
# stationarity_test False
# ('KEY', 'TXT') 0.00024277432702182218
# hedge_ratio_test -0.06072862517260136
# stationarity_test False
# ('KEY', 'TRV') 0.01572716669793083
# hedge_ratio_test 0.058389650491047974
# stationarity_test False
# ('KEY', 'TFC') 0.057477401136221455
# ('KEY', 'UNP') 0.15922163817780505
# ('KEY', 'UPS') 0.013804714187062132
# hedge_ratio_test 0.0993268427455183
# stationarity_test False
# ('KEY', 'UNH') 0.0019341912258520942
# hedge_ratio_test -0.034239256655021984
# stationarity_test False
# ('KEY', 'VRSK') 0.0006491642815343966
# hedge_ratio_test -0.013909873374586948
# stationarity_test False
# ('KEY', 'VZ') 0.003876248655140179
# hedge_ratio_test -0.10534646253441932
# stationarity_test False
# ('KEY', 'V') 0.00837800172910346
# hedge_ratio_test 0.03963945621564767
# stationarity_test False
# ('KEY', 'WRB') 0.0006076614247695254
# hedge_ratio_test -0.018908569202736043
# stationarity_test False
# ('KEY', 'WM') 0.012864941630464281
# hedge_ratio_test 0.051133501077794144
# stationarity_test False
# ('KEY', 'WFC') 0.127034459465809
# ('KEY', 'XYL') 0.3469602694266316
# ('KHC', 'MCO') 0.0011622282838618324
# hedge_ratio_test 0.15761386079640918
# stationarity_test False
# ('LW', 'LMT') 0.24961597024738802
# ('LW', 'VZ') 0.02325541886475964
# hedge_ratio_test -1.451442290521376
# stationarity_test False
# ('LMT', 'MAR') 0.002251488419491919
# hedge_ratio_test 0.19949944969133138
# stationarity_test False
# ('LMT', 'MMC') 6.078440246819938e-05
# hedge_ratio_test 0.44247071971523444
# stationarity_test False
# ('LMT', 'MA') 0.029542987244009382
# hedge_ratio_test 0.12673607031809336
# stationarity_test False
# ('LMT', 'MET') 0.017883251940745384
# hedge_ratio_test 1.1051470026576684
# stationarity_test False
# ('LMT', 'TAP') 0.023491638564077585
# hedge_ratio_test 0.8971258009787926
# stationarity_test False
# ('LMT', 'OMC') 0.02420595295909895
# hedge_ratio_test 0.4862658497284773
# stationarity_test False
# ('LMT', 'OTIS') 0.0038088244543687476
# hedge_ratio_test 0.7837403963720524
# stationarity_test False
# ('LMT', 'PAYX') 0.09585118100263845
# ('LMT', 'PFG') 0.04578174504748227
# hedge_ratio_test 0.7066086694771849
# stationarity_test False
# ('LMT', 'RJF') 0.0004580967084843808
# hedge_ratio_test 0.7253033528688568
# stationarity_test False
# ('LMT', 'RSG') 0.015532746323870505
# hedge_ratio_test 0.5643204965870098
# stationarity_test False
# ('LMT', 'SBUX') 0.023571272168125147
# hedge_ratio_test 0.7216369105824598
# stationarity_test False
# ('LMT', 'STT') 0.015442661685383118
# hedge_ratio_test 0.6801088594356073
# stationarity_test False
# ('LMT', 'VZ') 0.0005137316540080541
# hedge_ratio_test -2.1365000480181315
# stationarity_test False
# ('LMT', 'V') 0.004593611058495222
# hedge_ratio_test 0.40656024027558324
# stationarity_test False
# ('LMT', 'WM') 0.07949153174535212
# ('LMT', 'WFC') 0.07275927187432171
# ('LMT', 'XYL') 0.054293181172534864
# ('MTB', 'MAR') 0.0011642558843345037
# hedge_ratio_test 0.09840145781541582
# stationarity_test False
# ('MTB', 'MMC') 0.00016698598267498834
# hedge_ratio_test 0.03470032458209471
# stationarity_test False
# ('MTB', 'MA') 7.32048570645768e-05
# hedge_ratio_test -0.09943940414329672
# stationarity_test False
# ('MTB', 'MKC') 0.00026091375919297806
# hedge_ratio_test 0.28881085513621785
# stationarity_test False
# ('MTB', 'MCD') 0.007510096195431861
# hedge_ratio_test 0.3103332530899418
# stationarity_test False
# ('MTB', 'MRK') 7.194846795977162e-05
# hedge_ratio_test 0.21570575251595406
# stationarity_test False
# ('MTB', 'MET') 0.014312849519585544
# hedge_ratio_test 1.3007996188300734
# stationarity_test False
# ('MTB', 'TAP') 0.09358953602410125
# ('MTB', 'MDLZ') 0.00014678872186327656
# hedge_ratio_test 0.6208257078968971
# stationarity_test False
# ('MTB', 'MCO') 0.045404708343188
# hedge_ratio_test 0.1583386206771891
# stationarity_test False
# ('MTB', 'NDAQ') 0.00010150506168413581
# hedge_ratio_test 0.08311793902879555
# stationarity_test False
# ('MTB', 'NSC') 0.00016631859952129054
# hedge_ratio_test 0.14673623318988446
# stationarity_test False
# ('MTB', 'NTRS') 0.00036515124181972817
# hedge_ratio_test 0.46519236783935697
# stationarity_test False
# ('MTB', 'NUE') 0.00029255595724764655
# hedge_ratio_test -0.022710213700531272
# stationarity_test False
# ('MTB', 'OMC') 0.00713250686494855
# hedge_ratio_test 0.5594570522278342
# stationarity_test False
# ('MTB', 'ORCL') 0.00011781425745631715
# hedge_ratio_test 0.005497665739269006
# stationarity_test False
# ('MTB', 'OTIS') 0.009490600926567914
# hedge_ratio_test 0.6049816607037404
# stationarity_test False
# ('MTB', 'PCAR') 0.0003184306424216044
# hedge_ratio_test 0.04580979021447423
# stationarity_test False
# ('MTB', 'PAYX') 0.0016447020904711178
# hedge_ratio_test 0.3119580309495825
# stationarity_test False
# ('MTB', 'PEP') 3.0518360837391056e-05
# hedge_ratio_test 0.12483128550956002
# stationarity_test False
# ('MTB', 'PFE') 0.00012741542008573809
# hedge_ratio_test 1.4388180407109676
# stationarity_test False
# ('MTB', 'PM') 0.0001316893373418006
# hedge_ratio_test 0.030338052853986608
# stationarity_test False
# ('MTB', 'PNC') 0.03522217507246515
# hedge_ratio_test 0.4743327332054662
# stationarity_test False
# ('MTB', 'PPG') 0.0021010745157860906
# hedge_ratio_test 0.24467720643420776
# stationarity_test False
# ('MTB', 'PFG') 0.2217682832611962
# ('MTB', 'PG') 0.00015034218636259542
# hedge_ratio_test 0.00012643099392246893
# stationarity_test False
# ('MTB', 'PRU') 0.002252457123543515
# hedge_ratio_test 0.1853884054723175
# stationarity_test False
# ('MTB', 'RJF') 0.0002347938177321529
# hedge_ratio_test 0.07069389299752143
# stationarity_test False
# ('MTB', 'RTX') 5.556156318970979e-05
# hedge_ratio_test 0.4522647116006254
# stationarity_test False
# ('MTB', 'RF') 0.004860321815257705
# hedge_ratio_test 2.7528430150088274
# stationarity_test False
# ('MTB', 'RSG') 0.0001494767025105099
# hedge_ratio_test 0.17189008529074712
# stationarity_test False
# ('MTB', 'ROL') 0.00028873879149418565
# hedge_ratio_test 0.6959892341910254
# stationarity_test False
# ('MTB', 'SPGI') 0.00010581058815492482
# hedge_ratio_test 0.059329984330144636
# stationarity_test False
# ('MTB', 'SHW') 0.000462744515824664
# hedge_ratio_test 0.02216869508615632
# stationarity_test False
# ('MTB', 'SBUX') 0.00021743682503871969
# hedge_ratio_test -0.08782650532666308
# stationarity_test False
# ('MTB', 'STT') 0.0004585659881067222
# hedge_ratio_test 0.32362911476790157
# stationarity_test False
# ('MTB', 'STLD') 7.13531867094751e-05
# hedge_ratio_test 0.029945269625000423
# stationarity_test False
# ('MTB', 'TMUS') 0.00043986525701360187
# hedge_ratio_test 0.03895127668335874
# stationarity_test False
# ('MTB', 'TXT') 0.0001392152482273435
# hedge_ratio_test -0.12909855779544607
# stationarity_test False
# ('MTB', 'TRV') 0.009879410870495141
# hedge_ratio_test 0.4681003407910708
# stationarity_test False
# ('MTB', 'TFC') 0.0062981977350023465
# hedge_ratio_test 0.6393778902570088
# stationarity_test False
# ('MTB', 'USB') 0.07379426004735984
# ('MTB', 'UNP') 0.09801144453671334
# ('MTB', 'UNH') 0.00024359769037040908
# hedge_ratio_test -0.19341092217187064
# stationarity_test False
# ('MTB', 'VRSK') 0.00016553316928502823
# hedge_ratio_test -0.02519246170943895
# stationarity_test False
# ('MTB', 'VZ') 0.0013137042987044364
# hedge_ratio_test -0.7312687507532343
# stationarity_test False
# ('MTB', 'V') 0.00041609826213184504
# hedge_ratio_test 0.08380510044746786
# stationarity_test False
# ('MTB', 'WRB') 0.000135334238072365
# hedge_ratio_test 0.18671347820197304
# stationarity_test False
# ('MTB', 'WM') 0.019637206974583574
# hedge_ratio_test 0.5418164641582721
# stationarity_test False
# ('MTB', 'WFC') 0.004695324375888159
# hedge_ratio_test 0.5839230160823805
# stationarity_test False
# ('MTB', 'XYL') 0.031300669897105934
# hedge_ratio_test 0.7372460398875068
# stationarity_test False
# ('MMC', 'TAP') 0.3905917514560321
# ('MKC', 'NUE') 0.006074405370857575
# hedge_ratio_test -0.24527770424585016
# stationarity_test False
# ('MKC', 'PFE') 0.004533537178410391
# hedge_ratio_test -1.2198634775287092
# stationarity_test False
# ('MKC', 'STLD') 0.0009156778585384325
# hedge_ratio_test -0.28375896348612706
# stationarity_test False
# ('MET', 'VZ') 0.0044326616875293165
# hedge_ratio_test -1.1136501061319775
# stationarity_test False
# ('TAP', 'VZ') 0.014096298875868508
# hedge_ratio_test -0.6930719202119315
# stationarity_test False
# ('MDLZ', 'PAYX') 1.718247919288753e-07
# hedge_ratio_test 0.4521910448534711
# stationarity_test True
# ('MDLZ', 'PFE') 0.10291816881001165
# ('MDLZ', 'PPG') 0.0013778614834965494
# hedge_ratio_test 0.297539459467577
# stationarity_test False
# ('MDLZ', 'ROL') 0.010928479239225602
# hedge_ratio_test 1.1157605548409704
# stationarity_test False
# ('MCO', 'ORCL') 0.07549165969590105
# ('MCO', 'PCAR') 0.00178334316208177
# hedge_ratio_test 1.4023716640988415
# stationarity_test False
# ('MCO', 'PFE') 0.03179426081244195
# hedge_ratio_test -2.514507733761451
# stationarity_test False
# ('MCO', 'PFG') 0.0041220952079498415
# hedge_ratio_test 3.9926941100370668
# stationarity_test True
# ('MCO', 'PRU') 0.00378418803344969
# hedge_ratio_test 1.3637426173067573
# stationarity_test False
# ('MCO', 'RTX') 0.16460938996686864
# ('MCO', 'ROL') 9.748818659951035e-05
# hedge_ratio_test 6.932445452075978
# stationarity_test False
# ('MCO', 'TMUS') 0.00016121821037429196
# hedge_ratio_test 0.9265443411666775
# ...
# ('MKC', 'MCD') 0.0078642824567073
# hedge_ratio_test 0.19531314289196772
# stationarity_test False
# ('MKC', 'NDAQ') 0.06469703720119038
# ('MKC', 'NUE') 0.013851415232232794
# hedge_ratio_test 0.13295529400607808
# stationarity_test True
# ('MKC', 'PFE') 0.0017502911364245181
# hedge_ratio_test 0.5391460409883464
# stationarity_test False
# ('MKC', 'RTX') 0.005179125739918819
# hedge_ratio_test 0.31130972351224806
# stationarity_test False
# ('MKC', 'ROL') 0.006025971146622785
# hedge_ratio_test 0.9949069903898605
# stationarity_test False
# ('MKC', 'TT') 0.0012571489736736908
# hedge_ratio_test 0.21347558399001687
# stationarity_test True
# ('MKC', 'TRV') 0.00712001455729083
# hedge_ratio_test 0.26169185687665913
# stationarity_test False
# ('MKC', 'WM') 0.009390122002505814
# hedge_ratio_test 0.3073785212807066
# stationarity_test False
# ('MKC', 'XYL') 0.10599386024696567
# ('MCD', 'ROL') 0.0005247427353760089
# hedge_ratio_test 5.207156445368403
# stationarity_test False
# ('MCD', 'TRV') 0.010156319556204977
# hedge_ratio_test 1.0488388548533116
# stationarity_test False
# ('MRK', 'NDAQ') 0.0065369478301676885
# hedge_ratio_test 0.9278224689298545
# stationarity_test True
# ('MRK', 'NSC') 0.002141796899318395
# hedge_ratio_test 0.41663278827983
# stationarity_test False
# ('MRK', 'PCAR') 0.008611150900310876
# hedge_ratio_test 0.943387238378161
# stationarity_test False
# ('MRK', 'ROL') 0.0012004415473868392
# hedge_ratio_test 2.0453839902587454
# stationarity_test False
# ('MRK', 'TXT') 0.012827334883813959
# hedge_ratio_test 1.2558635856718434
# stationarity_test False
# ('MRK', 'TRV') 0.002674573609989299
# hedge_ratio_test 0.3909653381441524
# stationarity_test False
# ('MRK', 'TFC') 0.19907209256142017
# ('MRK', 'UNP') 0.008601296799670278
# hedge_ratio_test 0.3199912698114155
# stationarity_test False
# ('MRK', 'XYL') 0.02007510502732201
# hedge_ratio_test 0.6098290548705863
# stationarity_test True
# ('MET', 'NTRS') 0.010443937072777302
# hedge_ratio_test 0.3437676857338712
# stationarity_test True
# ('MET', 'ORCL') 0.012760744035162891
# hedge_ratio_test -0.09327094290787452
# stationarity_test True
# ('MET', 'OTIS') 0.01161755401281226
# hedge_ratio_test 0.6650218453623413
# stationarity_test True
# ('MET', 'PM') 0.008652585660841762
# hedge_ratio_test 0.4901485177837461
# stationarity_test False
# ('MET', 'SBUX') 0.022507999054176955
# hedge_ratio_test 0.3273753286297896
# stationarity_test True
# ('MET', 'TEL') 0.005228819531155996
# hedge_ratio_test 0.3672934281080902
# stationarity_test False
# ('MET', 'USB') 0.0026618730181494615
# hedge_ratio_test 0.4052934976011674
# stationarity_test True
# ('MET', 'UNH') 0.010945551342828543
# hedge_ratio_test 0.06218506322498623
# stationarity_test False
# ('MET', 'WM') 0.011100834608117324
# hedge_ratio_test -0.16569393957130707
# stationarity_test True
# ('TAP', 'NDAQ') 0.014197954425140174
# hedge_ratio_test -0.20058795552652686
# stationarity_test True
# ('TAP', 'NTRS') 0.004528227333821018
# hedge_ratio_test 0.4720225672268621
# stationarity_test False
# ('TAP', 'PAYX') 0.0013913958838164028
# hedge_ratio_test 0.08597832291785201
# stationarity_test True
# ('TAP', 'PFE') 0.059231215416522896
# ('TAP', 'SBUX') 0.000273953707281079
# hedge_ratio_test 0.386024711921776
# stationarity_test True
# ('MDLZ', 'TFC') 0.10041918763504304
# ('NDAQ', 'XYL') 0.00023980587982174503
# hedge_ratio_test 0.7010490450561255
# stationarity_test True
# ('NSC', 'TXT') 0.02304017960260042
# hedge_ratio_test 1.4961438919257162
# stationarity_test False
# ('NSC', 'TT') 0.038759508754715816
# hedge_ratio_test 0.4625661212238005
# stationarity_test False
# ('NSC', 'UNP') 0.008936245526149321
# hedge_ratio_test 0.5370099519728767
# stationarity_test False
# ('NSC', 'XYL') 0.01018251769446899
# hedge_ratio_test 0.6709049015799362
# stationarity_test False
# ('NTRS', 'PAYX') 0.0068934416156958495
# hedge_ratio_test 0.17817834825852827
# stationarity_test False
# ('NUE', 'OMC') 0.00953848792089077
# hedge_ratio_test -0.8570374231191354
# stationarity_test False
# ('NUE', 'PCAR') 0.00038609131181666616
# hedge_ratio_test 2.127082108875014
# stationarity_test False
# ('NUE', 'PAYX') 0.000896707439494042
# hedge_ratio_test -0.14052506322183006
# stationarity_test False
# ('NUE', 'PEP') 0.0018310356852496035
# hedge_ratio_test -0.35250156230847984
# stationarity_test False
# ('NUE', 'PFE') 0.0019761533992024073
# hedge_ratio_test 2.5912874765346077
# stationarity_test False
# ('NUE', 'PM') 0.0012917396205262754
# hedge_ratio_test -0.9821005855543918
# stationarity_test True
# ('NUE', 'PNC') 0.006336107499792749
# hedge_ratio_test 0.5045063161522367
# stationarity_test False
# ('NUE', 'PPG') 0.003527120379462464
# hedge_ratio_test -0.23762880807428122
# stationarity_test False
# ('NUE', 'PFG') 0.0023853800152069896
# hedge_ratio_test 1.7676273603251627
# stationarity_test False
# ('NUE', 'PRU') 0.0012850618927857738
# hedge_ratio_test 0.16703705095492993
# stationarity_test False
# ('NUE', 'RJF') 0.00892517734757799
# hedge_ratio_test 0.846118720973661
# stationarity_test False
# ('NUE', 'RTX') 0.0006180961337641084
# hedge_ratio_test 1.4390338146832127
# stationarity_test False
# ('NUE', 'RF') 0.0007200133980693163
# hedge_ratio_test 0.7904060535486614
# stationarity_test False
# ('NUE', 'ROL') 0.026343866286046316
# hedge_ratio_test 5.136490766073122
# stationarity_test False
# ('NUE', 'SPGI') 0.001768997482011138
# hedge_ratio_test -0.026689265625015557
# stationarity_test False
# ('NUE', 'SHW') 0.0025653122945937623
# hedge_ratio_test -0.13371669077659948
# stationarity_test False
# ('NUE', 'STT') 0.004368296667477824
# hedge_ratio_test -0.40046455252757296
# stationarity_test False
# ('NUE', 'TMUS') 0.00393205992849098
# hedge_ratio_test -0.385807348480556
# stationarity_test True
# ('NUE', 'TEL') 0.010958856082288373
# hedge_ratio_test -0.8203858781907094
# stationarity_test False
# ('NUE', 'TXT') 0.008821976369479257
# hedge_ratio_test 2.6830310882844683
# stationarity_test True
# ('NUE', 'TT') 0.011422010455378141
# hedge_ratio_test 0.8413636576393269
# stationarity_test False
# ('NUE', 'TRV') 0.0005940668946344689
# hedge_ratio_test 1.098398822301171
# stationarity_test False
# ('NUE', 'TFC') 0.02958466653547278
# hedge_ratio_test -1.9188664339908361
# stationarity_test True
# ('NUE', 'USB') 0.0013399432799960909
# hedge_ratio_test -1.8096266556175116
# stationarity_test False
# ('NUE', 'UNP') 0.002320241284071117
# hedge_ratio_test 0.2971165245444072
# stationarity_test False
# ('NUE', 'UPS') 0.0004317836299162069
# hedge_ratio_test -0.4390528013039338
# stationarity_test False
# ('NUE', 'UNH') 0.0004893456996495814
# hedge_ratio_test -0.3641596085186078
# stationarity_test True
# ('NUE', 'VRSK') 0.0049219169309842594
# hedge_ratio_test 0.3012775700190789
# stationarity_test False
# ('NUE', 'VZ') 0.0007147448620413364
# hedge_ratio_test 2.3970493574053497
# stationarity_test True
# ('NUE', 'V') 0.0009769892903144135
# hedge_ratio_test 1.5981759397213793
# stationarity_test False
# ('NUE', 'WM') 0.0072288720532211375
# hedge_ratio_test 1.3757961934329015
# stationarity_test False
# ('NUE', 'WFC') 0.0033265727843397727
# hedge_ratio_test -1.3614085375352303
# stationarity_test False
# ('NUE', 'XYL') 0.05405414599327772
# ('ORCL', 'PCAR') 0.011912004319849661
# hedge_ratio_test 0.9692225353859035
# stationarity_test False
# ('ORCL', 'PAYX') 0.00029855667834374967
# hedge_ratio_test -0.060449223267782015
# stationarity_test True
# ('ORCL', 'PEP') 0.0006042579322438699
# hedge_ratio_test 0.21984333262533506
# stationarity_test False
# ('ORCL', 'PFE') 0.011252542949021787
# hedge_ratio_test 1.387835436375885
# stationarity_test False
# ('ORCL', 'PM') 0.00039872134342880497
# hedge_ratio_test 0.017134615509552975
# stationarity_test False
# ('ORCL', 'PNC') 0.0006128568192202625
# hedge_ratio_test 0.026986047162603444
# stationarity_test False
# ('ORCL', 'PPG') 0.0005216024353347951
# hedge_ratio_test -0.033275465673756915
# stationarity_test False
# ('ORCL', 'PFG') 0.00018716984100961988
# hedge_ratio_test 0.38363222778547745
# stationarity_test False
# ('ORCL', 'PRU') 0.0005350038273858422
# hedge_ratio_test -0.06971807160295562
# stationarity_test False
# ('ORCL', 'RJF') 0.0003687959503442875
# hedge_ratio_test 0.4811789895314607
# stationarity_test False
# ('ORCL', 'RTX') 1.732213114439343e-05
# hedge_ratio_test 0.8101402142068648
# stationarity_test True
# ('ORCL', 'RF') 0.001063330470029646
# hedge_ratio_test -0.4635989909706115
# stationarity_test True
# ('ORCL', 'RSG') 0.0028579715500312796
# hedge_ratio_test 0.6012363162149251
# stationarity_test False
# ('ORCL', 'ROL') 0.008970721538235707
# hedge_ratio_test 2.923989121782765
# stationarity_test False
# ('ORCL', 'SPGI') 0.0002069913309918958
# hedge_ratio_test 0.11348496410564107
# stationarity_test False
# ('ORCL', 'SHW') 0.000593582231743386
# hedge_ratio_test -0.058762856990268564
# stationarity_test False
# ('ORCL', 'SBUX') 0.001885967507919517
# hedge_ratio_test -0.36089856960928235
# stationarity_test False
# ('ORCL', 'STT') 0.004171454765732062
# hedge_ratio_test -0.47066508473196844
# stationarity_test False
# ('ORCL', 'TMUS') 0.00031100654732956216
# hedge_ratio_test 0.38380080870689914
# stationarity_test False
# ('ORCL', 'TXT') 0.01448717267243248
# hedge_ratio_test 1.4759047510206031
# stationarity_test True
# ('ORCL', 'TRV') 0.00018452887771739732
# hedge_ratio_test 0.6120065146651902
# stationarity_test False
# ('ORCL', 'TFC') 0.09673672769143038
# ('ORCL', 'USB') 0.009090726275470178
# hedge_ratio_test -0.9660931277497445
# stationarity_test False
# ('ORCL', 'UNP') 0.0015256625517684748
# hedge_ratio_test 0.2741607196414657
# stationarity_test False
# ('ORCL', 'UPS') 0.0006898850920684173
# hedge_ratio_test -0.19416473410684978
# stationarity_test False
# ('ORCL', 'UNH') 0.0027043698778635404
# hedge_ratio_test -0.1356452988680645
# stationarity_test False
# ('ORCL', 'VRSK') 1.7632546215624586e-06
# hedge_ratio_test 0.4129537413618166
# stationarity_test False
# ('ORCL', 'VZ') 9.846975162977771e-06
# hedge_ratio_test 2.3829127477399155
# stationarity_test False
# ('ORCL', 'V') 0.0019822953518549968
# hedge_ratio_test 0.9232795405784016
# stationarity_test True
# ('ORCL', 'WM') 2.7088174770828112e-05
# hedge_ratio_test 1.1274938596791717
# stationarity_test True
# ('ORCL', 'XYL') 0.05583564280087372
# ('OTIS', 'STT') 0.00010651821233249666
# hedge_ratio_test 0.9883089793869195
# stationarity_test False
# ('PCAR', 'TXT') 0.02363202931386213
# hedge_ratio_test 1.0524965285478438
# stationarity_test False
# ('PCAR', 'TT') 0.0018685785061941806
# hedge_ratio_test 0.4295616031780196
# stationarity_test True
# ('PFE', 'UPS') 0.013903413801978442
# hedge_ratio_test -0.19979330912930376
# stationarity_test False
# ('PM', 'UNH') 0.0026457106845991867
# hedge_ratio_test 0.11939802782733411
# stationarity_test False
# ('RSG', 'VRSK') 0.01287240172163887
# hedge_ratio_test 0.3551526759806447
# stationarity_test False
# ('SPGI', 'TMUS') 0.012421085157797697
# hedge_ratio_test 2.696344074716722
# stationarity_test False
# ('SHW', 'TFC') 0.04195351236084381
# hedge_ratio_test 4.0821052554089565
# stationarity_test False
# ('SHW', 'UNP') 0.028748105969619714
# hedge_ratio_test 0.764080214476147
# stationarity_test False
# ('STT', 'UNP') 0.004814587653754117
# hedge_ratio_test 0.09526266547602333
# stationarity_test False
# ('STT', 'VRSK') 0.015230154016061603
# hedge_ratio_test 0.09740641169017664
# stationarity_test False
# ('TXT', 'TRV') 0.0031905739380361188
# hedge_ratio_test 0.29074506403666733
# stationarity_test False
# ('TT', 'TRV') 0.007736734805921885
# hedge_ratio_test 0.5808798062583065
# stationarity_test False
# ('TT', 'XYL') 0.0008435987370594569
# hedge_ratio_test 1.1443324139773345
# stationarity_test False
# ('TFC', 'UNP') 0.0011735648456793848
# hedge_ratio_test 0.09333311790938699
# stationarity_test False
# ('VRSK', 'WM') 0.014834812052339698
# hedge_ratio_test 0.6970992071652595
# stationarity_test False
# ('VZ', 'V') 0.0020051475114410263
# hedge_ratio_test 0.0539172941737284
# stationarity_test False
# ('VZ', 'WM') 0.013011699659643427
# hedge_ratio_test 0.06519970964399846
# stationarity_test False
# ('VZ', 'XYL') 0.02210615022626512
# hedge_ratio_test 0.018966919644831354
# stationarity_test False
# ('V', 'WFC') 0.002796944826336534
# hedge_ratio_test -0.36431033180050565
# stationarity_test True
# ('V', 'XYL') 0.08700053248422052
# ('LNT', 'DTE') 0.011311641268892137
# hedge_ratio_test 0.44988087213236494
# stationarity_test False
# ('LNT', 'NI') 0.0062393885024576694
# hedge_ratio_test 1.4908995161865575
# stationarity_test True
# ('LNT', 'PPL') 0.009926030272475666
# hedge_ratio_test 1.2137793623703435
# stationarity_test False
# ('LNT', 'XEL') 0.0005524360673482117
# hedge_ratio_test 0.7245865787161656
# stationarity_test False
# ('AEE', 'CMS') 0.00718310719159263
# hedge_ratio_test -0.012461607812439685
# stationarity_test False
# ('AEE', 'D') 0.00665820797081377
# hedge_ratio_test -0.039959849336288183
# stationarity_test False
# ('AEE', 'EIX') 0.054988505882439094
# ('AEE', 'FE') 0.009876486956635566
# hedge_ratio_test 0.14051806672412687
# stationarity_test False
# ('AEE', 'PPL') 0.008736785189892142
# hedge_ratio_test 0.21925372329515502
# stationarity_test False
# ('AEE', 'SO') 0.004688364123730009
# hedge_ratio_test -0.1470573000347891
# stationarity_test False
# ('AEP', 'ETR') 0.0013892087334156933
# hedge_ratio_test 0.9755787919678329
# stationarity_test False
# ('AEP', 'FE') 0.0011252753144260952
# hedge_ratio_test 2.3374899839638164
# stationarity_test True
# ('AEP', 'NI') 0.00914536669130205
# hedge_ratio_test 4.351035698575682
# stationarity_test False
# ('AEP', 'SO') 0.010612192884402578
# hedge_ratio_test 0.8546226471890542
# stationarity_test False
# ('CMS', 'ETR') 0.002768010071121359
# hedge_ratio_test 0.5196313826691564
# stationarity_test False
# ('CMS', 'SO') 0.0031202027685387273
# hedge_ratio_test 0.5130760825842756
# stationarity_test False
# ('ED', 'DUK') 0.006142829961339604
# hedge_ratio_test 0.6351077526493301
# stationarity_test False
# ('ED', 'EIX') 0.2686830920170198
# ('ED', 'ETR') 0.008531230218734965
# hedge_ratio_test 0.5118322249029207
# stationarity_test False
# ('ED', 'EVRG') 9.14253816698776e-06
# hedge_ratio_test 1.2119531619409913
# stationarity_test False
# ('ED', 'EXC') 0.010341421595043093
# hedge_ratio_test 0.4946331781840453
# stationarity_test False
# ('ED', 'NI') 0.003472818608674295
# hedge_ratio_test 2.5015865875709897
# stationarity_test True
# ('ED', 'PPL') 0.0014825080336519217
# hedge_ratio_test 1.5578051256543122
# stationarity_test False
# ('ED', 'SO') 0.013128551706565917
# hedge_ratio_test 0.36745899377507507
# stationarity_test False
# ('D', 'FE') 0.013683563213909474
# hedge_ratio_test 1.9798585421797592
# stationarity_test False
# ('ETR', 'NI') 0.012435355423428647
# hedge_ratio_test 4.523022311151433
# stationarity_test False
# ('ETR', 'PEG') 0.007067848070565517
# hedge_ratio_test 1.3647226662737755
# stationarity_test False
# ('EVRG', 'NI') 1.8857751155091389e-06
# hedge_ratio_test 1.6598925790959915
# stationarity_test False
# ('EVRG', 'PPL') 0.0020839502362954604
# hedge_ratio_test 0.939129913192302
# stationarity_test False
# ('EVRG', 'SO') 0.017494543638620012
# hedge_ratio_test 0.2236347212618338
# stationarity_test True
# ('EVRG', 'WEC') 0.009639524013007975
# hedge_ratio_test 0.4129277175428675
# stationarity_test True
# ('EVRG', 'XEL') 0.00580239411583922
# hedge_ratio_test 0.5010188911737273
# stationarity_test True
# ('EXC', 'SO') 0.00017768807089423017
# hedge_ratio_test -0.12301483214383029
# stationarity_test False
# ('NI', 'PEG') 0.005869469865840324
# hedge_ratio_test 0.2704665987388034
# stationarity_test False
# ('PEG', 'SO') 6.558099915535298e-05
# hedge_ratio_test 0.6028694806135887
# stationarity_test False
# ('AMT', 'VTR') 0.09853706590166755
# ('CPT', 'MAA') 0.0024895650643584964
# hedge_ratio_test 0.665242035210104
# stationarity_test False
# ('CPT', 'PLD') 0.007490703934331773
# hedge_ratio_test 0.4274321797181233
# stationarity_test False
# ('CCI', 'DLR') 0.14146541281425618
# ('DLR', 'VTR') 0.0021011405341541185
# hedge_ratio_test 2.1378462257260766
# stationarity_test True
# ('DLR', 'VICI') 4.780997376285194e-06
# hedge_ratio_test 4.707957947639798
# stationarity_test False
# ('EQR', 'INVH') 0.017461658533434635
# hedge_ratio_test 1.1917787337857049
# stationarity_test False
# ('O', 'VICI') 0.032957670367945856
# hedge_ratio_test 0.810419759883767
# stationarity_test False
# ('REG', 'UDR') 0.040293557590156286
# hedge_ratio_test 1.1733744086272468
# stationarity_test False
# ('VICI', 'WY') 0.0008700802301215822
# hedge_ratio_test 0.43567811671937784
# stationarity_test False
# ('MRO', 'SLB') 0.01244913838842393
# hedge_ratio_test 0.37659508035385325
# stationarity_test True
# Clustering for 12 2023
# DBSCAN(eps=1, min_samples=3)
#
# Clusters discovered: 11

# %%
import pandas as pd

def load_data_from_hdf5(hdf5_file_path):
    # Open the HDF5 file in read mode
    with pd.HDFStore(hdf5_file_path, mode='r') as store:
        # Access the 'features' dataset
        if '/features' in store.keys():
            features_df = store['features']
            print("Features Data Loaded")
            print(features_df.head())  # Display the first few rows
        else:
            print("Features dataset not found.")
            features_df = None

        # Access the 'stationarity_labels' dataset
        if '/stationarity_labels' in store.keys():
            labels_series = store['stationarity_labels']
            print("Stationarity Labels Loaded")
            print(labels_series.head())  # Display the first few labels
        else:
            print("Stationarity labels not found.")
            labels_series = None

        # Access the 'hedge_ratios' dataset
        if '/hedge_ratios' in store.keys():
            ratios_series = store['hedge_ratios']
            print("Hedge Ratios Loaded")
            print(ratios_series.head())  # Display the first few ratios
        else:
            print("Hedge ratios not found.")
            ratios_series = None

    return features_df, labels_series, ratios_series

# Specify the path to your HDF5 file
hdf5_file_path = "/content/drive/My Drive/NN_dataset.h5"

# Call the function and retrieve the data
features_df, labels_series, ratios_series = load_data_from_hdf5(hdf5_file_path)

# %%
features_df.shape
# Out:
# (862196, 8)
